# %%
x=2
y=[1,2,4]
z="sriya kolluru"
print(x,y,z,sep="\n")
# Out:
# 2
# [1, 2, 4]
# sriya kolluru

# %%
# sriya

# %%
print("sriya kolluru") # string
# Out:
# sriya kolluru

# %% [markdown]
# #exploratory data analysis
# ##basics of python
# ###Expt-0

# %%
print(2). # no double qoutes means no string
# Out:
# 2

# %%
ar = [1,2,5]
print(ar)
# Out:
# [1, 2, 5]

# %%
print([1,2,5])
# Out:
# [1, 2, 5]

# %%
print ("anurag mahajan")
print(2)
print([1,2,5])
print("[anurag mahajamn"])
