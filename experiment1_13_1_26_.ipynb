# %% [markdown]
# <a href="https://colab.research.google.com/github/sriyakolluru0204/exp-0/blob/main/experiment1_13_1_26_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Sriya kolluru 2507012310
## Aim: Introduction to python

# %%
x = "apple"
y= "orange"
z = "cherry"
print(x,y,z)
# Out:
# apple orange cherry

# %%
x,y,z = "apple","cherry","orange"
print(x,y,z,sep="\n")
# Out:
# apple
# cherry
# orange

# %%
x,y,w,z=2,2.5,"anurag",True
print(type(x),type(y),type(w),type(z),sep="\n")
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
a,b = 10,5
print("sum=",a+b)
print("sub=",a-b)
print("mult=",a*b)
print("div=",a/b)
print("exp=",a**b)
# Out:
# sum= 15
# sub= 5
# mult= 50
# div= 2.0
# exp= 100000

# %%
a=int(input("enter the value of a="))
# Out:
# enter the value of a=4

# %%
a=int(input("enter the value of a="))
b=int(input("enter the value of b="))
print("\ns""um=",a+b,"\n""sub=",a-b,"\n""mult=",a*b,"\nd""iv=",a/b,"\n""exp=",a**b,)
# Out:
# enter the value of a=6
# enter the value of b=7
#
# sum= 13
# sub= -1
# mult= 42
# div= 0.8571428571428571
# exp= 279936

# %%
import math
pi= math.pi
r=float(input("enter the value of r="))
print("area of a circle=",pi*r*r)
# Out:
# enter the value of r=6
# area of a circle= 113.09733552923255

# %%
import math
math.log10(10)
# Out:
# 1.0

# %%
a=int(input("enter the value of a="))
b=int(input("enter the value of b="))

if(a>b):
  print("a is greater than b")

else:
  print("b is greater than a")
# Out:
# enter the value of a=3
# enter the value of b=7
# b is greater than a
